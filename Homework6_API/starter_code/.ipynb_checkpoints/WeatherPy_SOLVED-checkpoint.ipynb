# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
import config
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 594

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=25d95a902b40b8567c1cf7c2534a5333&units=imperial&q='

# %%
# list for response results
temp = []
counter = 1
set = 1

# loop through cities, make API request, and append desired results
for city in cities:
    try:
        response = requests.get(query_url + city).json()
        temp.append(response['main']['temp'])
        print(f'Processing Record {counter} of Set {set} | {city}')
        counter +=1
        
        if counter >50:
            set +=1
            counter = 1
        
    except KeyError:
        print(f'City not found. Skipping...')
        pass
# Out:
# Processing Record 1 of Set 1 | new norfolk
# Processing Record 2 of Set 1 | palauig
# Processing Record 3 of Set 1 | san cristobal
# Processing Record 4 of Set 1 | barrow
# City not found. Skipping...
# Processing Record 5 of Set 1 | port alfred
# Processing Record 6 of Set 1 | paamiut
# Processing Record 7 of Set 1 | kijang
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | mahebourg
# Processing Record 10 of Set 1 | ushuaia
# City not found. Skipping...
# Processing Record 11 of Set 1 | vallenar
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | dunedin
# Processing Record 16 of Set 1 | russell
# Processing Record 17 of Set 1 | touros
# Processing Record 18 of Set 1 | ribeira grande
# Processing Record 19 of Set 1 | bredasdorp
# Processing Record 20 of Set 1 | mehtar lam
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | arlit
# Processing Record 23 of Set 1 | vao
# Processing Record 24 of Set 1 | vaini
# City not found. Skipping...
# Processing Record 25 of Set 1 | carnarvon
# Processing Record 26 of Set 1 | skjervoy
# Processing Record 27 of Set 1 | bang krathum
# Processing Record 28 of Set 1 | bani walid
# Processing Record 29 of Set 1 | luganville
# Processing Record 30 of Set 1 | mandan
# Processing Record 31 of Set 1 | traiguen
# Processing Record 32 of Set 1 | sobolevo
# Processing Record 33 of Set 1 | rapid valley
# Processing Record 34 of Set 1 | mount gambier
# Processing Record 35 of Set 1 | cherskiy
# City not found. Skipping...
# Processing Record 36 of Set 1 | albany
# Processing Record 37 of Set 1 | nemuro
# Processing Record 38 of Set 1 | poum
# Processing Record 39 of Set 1 | kuri
# Processing Record 40 of Set 1 | lasa
# Processing Record 41 of Set 1 | sao filipe
# Processing Record 42 of Set 1 | esperance
# Processing Record 43 of Set 1 | warmbad
# Processing Record 44 of Set 1 | honiara
# Processing Record 45 of Set 1 | lavrentiya
# City not found. Skipping...
# Processing Record 46 of Set 1 | tuatapere
# Processing Record 47 of Set 1 | tiksi
# Processing Record 48 of Set 1 | kiunga
# Processing Record 49 of Set 1 | jamestown
# Processing Record 50 of Set 1 | gat
# Processing Record 1 of Set 2 | ewa beach
# Processing Record 2 of Set 2 | dondo
# Processing Record 3 of Set 2 | constitucion
# Processing Record 4 of Set 2 | dikson
# Processing Record 5 of Set 2 | slave lake
# Processing Record 6 of Set 2 | gornopravdinsk
# Processing Record 7 of Set 2 | angul
# Processing Record 8 of Set 2 | bluff
# Processing Record 9 of Set 2 | atuona
# City not found. Skipping...
# Processing Record 10 of Set 2 | sitka
# Processing Record 11 of Set 2 | chuy
# Processing Record 12 of Set 2 | cape town
# Processing Record 13 of Set 2 | jalu
# Processing Record 14 of Set 2 | saint george
# Processing Record 15 of Set 2 | talnakh
# Processing Record 16 of Set 2 | coihaique
# Processing Record 17 of Set 2 | kodiak
# City not found. Skipping...
# Processing Record 18 of Set 2 | clyde river
# Processing Record 19 of Set 2 | sao geraldo do araguaia
# Processing Record 20 of Set 2 | san patricio
# Processing Record 21 of Set 2 | hobart
# Processing Record 22 of Set 2 | rio cuarto
# Processing Record 23 of Set 2 | hamilton
# City not found. Skipping...
# Processing Record 24 of Set 2 | teguldet
# Processing Record 25 of Set 2 | haines junction
# Processing Record 26 of Set 2 | upernavik
# Processing Record 27 of Set 2 | tuktoyaktuk
# Processing Record 28 of Set 2 | kamenskiy
# Processing Record 29 of Set 2 | faanui
# Processing Record 30 of Set 2 | san buenaventura
# Processing Record 31 of Set 2 | hasaki
# Processing Record 32 of Set 2 | mbanza-ngungu
# Processing Record 33 of Set 2 | ilulissat
# Processing Record 34 of Set 2 | erenhot
# Processing Record 35 of Set 2 | nikolskoye
# Processing Record 36 of Set 2 | roma
# Processing Record 37 of Set 2 | gangelt
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 38 of Set 2 | boyolangu
# Processing Record 39 of Set 2 | caxito
# Processing Record 40 of Set 2 | arraial do cabo
# Processing Record 41 of Set 2 | haapiti
# Processing Record 42 of Set 2 | chingirlau
# Processing Record 43 of Set 2 | codrington
# Processing Record 44 of Set 2 | saldanha
# City not found. Skipping...
# Processing Record 45 of Set 2 | kahului
# Processing Record 46 of Set 2 | lewistown
# Processing Record 47 of Set 2 | raudeberg
# Processing Record 48 of Set 2 | salalah
# Processing Record 49 of Set 2 | kapaa
# Processing Record 50 of Set 2 | mackay
# Processing Record 1 of Set 3 | ikom
# City not found. Skipping...
# Processing Record 2 of Set 3 | avarua
# Processing Record 3 of Set 3 | uberlandia
# Processing Record 4 of Set 3 | pevek
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 5 of Set 3 | nome
# Processing Record 6 of Set 3 | arenapolis
# Processing Record 7 of Set 3 | enfield
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 8 of Set 3 | lorengau
# Processing Record 9 of Set 3 | ust-nera
# City not found. Skipping...
# Processing Record 10 of Set 3 | terrell
# Processing Record 11 of Set 3 | butaritari
# Processing Record 12 of Set 3 | port elizabeth
# Processing Record 13 of Set 3 | ucluelet
# Processing Record 14 of Set 3 | ormara
# Processing Record 15 of Set 3 | oktyabrskiy
# Processing Record 16 of Set 3 | saint-philippe
# Processing Record 17 of Set 3 | yellowknife
# Processing Record 18 of Set 3 | thompson
# Processing Record 19 of Set 3 | liling
# Processing Record 20 of Set 3 | tessalit
# Processing Record 21 of Set 3 | barranca
# Processing Record 22 of Set 3 | berdigestyakh
# Processing Record 23 of Set 3 | hithadhoo
# Processing Record 24 of Set 3 | labuan
# Processing Record 25 of Set 3 | saint-pierre
# Processing Record 26 of Set 3 | nueva helvecia
# Processing Record 27 of Set 3 | onega
# Processing Record 28 of Set 3 | airai
# Processing Record 29 of Set 3 | grand-santi
# Processing Record 30 of Set 3 | los llanos de aridane
# Processing Record 31 of Set 3 | aizpute
# Processing Record 32 of Set 3 | obo
# Processing Record 33 of Set 3 | castro
# City not found. Skipping...
# Processing Record 34 of Set 3 | saskylakh
# Processing Record 35 of Set 3 | puerto ayora
# City not found. Skipping...
# Processing Record 36 of Set 3 | bethel
# Processing Record 37 of Set 3 | port keats
# Processing Record 38 of Set 3 | ngunguru
# Processing Record 39 of Set 3 | caraballeda
# Processing Record 40 of Set 3 | high level
# Processing Record 41 of Set 3 | mar del plata
# Processing Record 42 of Set 3 | lebu
# Processing Record 43 of Set 3 | pindiga
# Processing Record 44 of Set 3 | georgetown
# Processing Record 45 of Set 3 | souillac
# Processing Record 46 of Set 3 | mariental
# Processing Record 47 of Set 3 | aklavik
# Processing Record 48 of Set 3 | ambon
# Processing Record 49 of Set 3 | ust-karsk
# Processing Record 50 of Set 3 | morondava
# City not found. Skipping...
# Processing Record 1 of Set 4 | geraldton
# Processing Record 2 of Set 4 | namasuba
# Processing Record 3 of Set 4 | severo-kurilsk
# Processing Record 4 of Set 4 | sao joao da barra
# Processing Record 5 of Set 4 | puerto madryn
# Processing Record 6 of Set 4 | bambanglipuro
# Processing Record 7 of Set 4 | hualmay
# Processing Record 8 of Set 4 | puerto baquerizo moreno
# Processing Record 9 of Set 4 | kruisfontein
# Processing Record 10 of Set 4 | aboso
# Processing Record 11 of Set 4 | fairbanks
# City not found. Skipping...
# Processing Record 12 of Set 4 | muroto
# Processing Record 13 of Set 4 | hilo
# City not found. Skipping...
# Processing Record 14 of Set 4 | tura
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 15 of Set 4 | pangkalanbuun
# Processing Record 16 of Set 4 | fortuna
# Processing Record 17 of Set 4 | sedro-woolley
# Processing Record 18 of Set 4 | bud
# Processing Record 19 of Set 4 | capreol
# Processing Record 20 of Set 4 | orlovskiy
# Processing Record 21 of Set 4 | tasiilaq
# Processing Record 22 of Set 4 | marathon
# Processing Record 23 of Set 4 | acapulco
# Processing Record 24 of Set 4 | sulphur
# Processing Record 25 of Set 4 | provideniya
# Processing Record 26 of Set 4 | kanye
# Processing Record 27 of Set 4 | biak
# Processing Record 28 of Set 4 | huarmey
# Processing Record 29 of Set 4 | grindavik
# Processing Record 30 of Set 4 | kilosa
# Processing Record 31 of Set 4 | sola
# Processing Record 32 of Set 4 | ulaanbaatar
# Processing Record 33 of Set 4 | vila velha
# Processing Record 34 of Set 4 | luderitz
# Processing Record 35 of Set 4 | alice springs
# Processing Record 36 of Set 4 | guerrero negro
# Processing Record 37 of Set 4 | alekseyevka
# Processing Record 38 of Set 4 | shitkino
# City not found. Skipping...
# Processing Record 39 of Set 4 | altay
# Processing Record 40 of Set 4 | torbay
# City not found. Skipping...
# Processing Record 41 of Set 4 | vostok
# Processing Record 42 of Set 4 | vestmanna
# Processing Record 43 of Set 4 | moscow
# Processing Record 44 of Set 4 | hanzhong
# Processing Record 45 of Set 4 | rincon
# Processing Record 46 of Set 4 | brokopondo
# Processing Record 47 of Set 4 | vestmannaeyjar
# Processing Record 48 of Set 4 | makakilo city
# City not found. Skipping...
# Processing Record 49 of Set 4 | east london
# Processing Record 50 of Set 4 | kralendijk
# Processing Record 1 of Set 5 | san borja
# Processing Record 2 of Set 5 | san francisco
# Processing Record 3 of Set 5 | ikalamavony
# Processing Record 4 of Set 5 | foz
# Processing Record 5 of Set 5 | mogadishu
# Processing Record 6 of Set 5 | cayenne
# City not found. Skipping...
# Processing Record 7 of Set 5 | jinka
# Processing Record 8 of Set 5 | kodinar
# Processing Record 9 of Set 5 | tiarei
# Processing Record 10 of Set 5 | iqaluit
# Processing Record 11 of Set 5 | latung
# Processing Record 12 of Set 5 | marsh harbour
# City not found. Skipping...
# Processing Record 13 of Set 5 | shache
# Processing Record 14 of Set 5 | qaanaaq
# Processing Record 15 of Set 5 | charters towers
# Processing Record 16 of Set 5 | chernyshevskiy
# Processing Record 17 of Set 5 | henties bay
# Processing Record 18 of Set 5 | valparaiso
# Processing Record 19 of Set 5 | nueva loja
# Processing Record 20 of Set 5 | somvarpet
# Processing Record 21 of Set 5 | ozernovskiy
# Processing Record 22 of Set 5 | victoria
# Processing Record 23 of Set 5 | brae
# Processing Record 24 of Set 5 | caucaia
# Processing Record 25 of Set 5 | wonthaggi
# City not found. Skipping...
# Processing Record 26 of Set 5 | ponta do sol
# Processing Record 27 of Set 5 | margate
# Processing Record 28 of Set 5 | serafimovich
# Processing Record 29 of Set 5 | chokurdakh
# Processing Record 30 of Set 5 | cabo san lucas
# Processing Record 31 of Set 5 | avera
# Processing Record 32 of Set 5 | manicore
# Processing Record 33 of Set 5 | tomatlan
# Processing Record 34 of Set 5 | lalsk
# Processing Record 35 of Set 5 | galesong
# Processing Record 36 of Set 5 | suntar
# Processing Record 37 of Set 5 | wembley
# Processing Record 38 of Set 5 | williston
# Processing Record 39 of Set 5 | baiao
# Processing Record 40 of Set 5 | ajdabiya
# Processing Record 41 of Set 5 | san vicente
# Processing Record 42 of Set 5 | yulara
# Processing Record 43 of Set 5 | kendari
# Processing Record 44 of Set 5 | kinablangan
# Processing Record 45 of Set 5 | copiapo
# Processing Record 46 of Set 5 | letka
# Processing Record 47 of Set 5 | poitiers
# Processing Record 48 of Set 5 | samarai
# Processing Record 49 of Set 5 | arauca
# Processing Record 50 of Set 5 | pismo beach
# Processing Record 1 of Set 6 | nanortalik
# Processing Record 2 of Set 6 | ahipara
# Processing Record 3 of Set 6 | polyanka
# Processing Record 4 of Set 6 | lompoc
# Processing Record 5 of Set 6 | pimentel
# Processing Record 6 of Set 6 | jacareacanga
# City not found. Skipping...
# Processing Record 7 of Set 6 | les cayes
# Processing Record 8 of Set 6 | urengoy
# Processing Record 9 of Set 6 | laguna
# Processing Record 10 of Set 6 | college
# Processing Record 11 of Set 6 | chumikan
# Processing Record 12 of Set 6 | muros
# Processing Record 13 of Set 6 | banda aceh
# Processing Record 14 of Set 6 | mehamn
# City not found. Skipping...
# Processing Record 15 of Set 6 | sept-iles
# Processing Record 16 of Set 6 | tonekabon
# Processing Record 17 of Set 6 | alta floresta
# Processing Record 18 of Set 6 | abu dhabi
# Processing Record 19 of Set 6 | narsaq
# Processing Record 20 of Set 6 | selikhino
# Processing Record 21 of Set 6 | bara
# Processing Record 22 of Set 6 | teberda
# Processing Record 23 of Set 6 | zeya
# Processing Record 24 of Set 6 | yantzaza
# Processing Record 25 of Set 6 | basco
# Processing Record 26 of Set 6 | leningradskiy
# City not found. Skipping...
# Processing Record 27 of Set 6 | shiloh
# Processing Record 28 of Set 6 | marawi
# Processing Record 29 of Set 6 | hailey
# Processing Record 30 of Set 6 | ladyzhyn
# Processing Record 31 of Set 6 | miles city
# Processing Record 32 of Set 6 | belgrade
# Processing Record 33 of Set 6 | plettenberg bay
# Processing Record 34 of Set 6 | monclova
# Processing Record 35 of Set 6 | cidreira
# Processing Record 36 of Set 6 | payo
# City not found. Skipping...
# Processing Record 37 of Set 6 | kang
# City not found. Skipping...
# Processing Record 38 of Set 6 | la sarre
# Processing Record 39 of Set 6 | ilasan
# Processing Record 40 of Set 6 | khatanga
# Processing Record 41 of Set 6 | isiro
# Processing Record 42 of Set 6 | hambantota
# Processing Record 43 of Set 6 | padang
# Processing Record 44 of Set 6 | shangrao
# City not found. Skipping...
# Processing Record 45 of Set 6 | boguchany
# Processing Record 46 of Set 6 | mayna
# Processing Record 47 of Set 6 | grand baie
# Processing Record 48 of Set 6 | witu
# Processing Record 49 of Set 6 | hibbing
# Processing Record 50 of Set 6 | nantucket
# Processing Record 1 of Set 7 | kenora
# Processing Record 2 of Set 7 | broken hill
# Processing Record 3 of Set 7 | laizhou
# City not found. Skipping...
# Processing Record 4 of Set 7 | insar
# Processing Record 5 of Set 7 | verkhoyansk
# Processing Record 6 of Set 7 | vanavara
# Processing Record 7 of Set 7 | allada
# City not found. Skipping...
# Processing Record 8 of Set 7 | bilibino
# Processing Record 9 of Set 7 | sivaki
# Processing Record 10 of Set 7 | gold coast
# Processing Record 11 of Set 7 | rawatsar
# City not found. Skipping...
# Processing Record 12 of Set 7 | scarborough
# Processing Record 13 of Set 7 | tocopilla
# Processing Record 14 of Set 7 | boda
# Processing Record 15 of Set 7 | stokmarknes
# Processing Record 16 of Set 7 | hudson bay
# Processing Record 17 of Set 7 | roebourne
# Processing Record 18 of Set 7 | kavaratti
# City not found. Skipping...
# Processing Record 19 of Set 7 | havoysund
# Processing Record 20 of Set 7 | coquimbo
# Processing Record 21 of Set 7 | myaundzha
# Processing Record 22 of Set 7 | kitui
# Processing Record 23 of Set 7 | kavieng
# City not found. Skipping...
# Processing Record 24 of Set 7 | nosy varika
# Processing Record 25 of Set 7 | toul
# Processing Record 26 of Set 7 | buenos aires
# Processing Record 27 of Set 7 | ruteng
# Processing Record 28 of Set 7 | ler
# Processing Record 29 of Set 7 | kaeo
# Processing Record 30 of Set 7 | garowe
# Processing Record 31 of Set 7 | yenagoa
# Processing Record 32 of Set 7 | tsiroanomandidy
# Processing Record 33 of Set 7 | vilcun
# Processing Record 34 of Set 7 | baruun-urt
# Processing Record 35 of Set 7 | puerto carreno
# Processing Record 36 of Set 7 | lagoa
# Processing Record 37 of Set 7 | oranjemund
# City not found. Skipping...
# Processing Record 38 of Set 7 | blythe
# Processing Record 39 of Set 7 | novo aripuana
# Processing Record 40 of Set 7 | grand gaube
# Processing Record 41 of Set 7 | bambous virieux
# Processing Record 42 of Set 7 | kiruna
# Processing Record 43 of Set 7 | homer
# City not found. Skipping...
# Processing Record 44 of Set 7 | komsomolskiy
# Processing Record 45 of Set 7 | buraydah
# Processing Record 46 of Set 7 | sergeyevka
# Processing Record 47 of Set 7 | yaan
# Processing Record 48 of Set 7 | klaksvik
# City not found. Skipping...
# Processing Record 49 of Set 7 | katsuura
# Processing Record 50 of Set 7 | panalingaan
# Processing Record 1 of Set 8 | nefteyugansk
# Processing Record 2 of Set 8 | maniitsoq
# Processing Record 3 of Set 8 | aykhal
# Processing Record 4 of Set 8 | georgiyevka
# Processing Record 5 of Set 8 | gunnedah
# Processing Record 6 of Set 8 | dolores
# Processing Record 7 of Set 8 | masuda
# Processing Record 8 of Set 8 | taiyuan
# Processing Record 9 of Set 8 | quarai
# Processing Record 10 of Set 8 | canmore
# Processing Record 11 of Set 8 | puerto escondido
# Processing Record 12 of Set 8 | rio grande
# Processing Record 13 of Set 8 | banjar
# Processing Record 14 of Set 8 | progreso
# Processing Record 15 of Set 8 | tarpon springs

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Create dictionary with all variables, called from the API
name = []
temp = []
humid = []
cloud = []
wind = []
lat = []
long = []
country = []
date = []
temp_max = []

# loop through cities, make API request, and append desired results to list names
for city in cities:
    try:
        response = requests.get(query_url + city).json()
        name.append(response['name'])
        humid.append(response['main']['humidity'])
        temp.append(response['main']['temp'])
        cloud.append(response['clouds']['all'])
        wind.append(response['wind']['speed'])
        lat.append(response['coord']['lat'])
        long.append(response['coord']['lon'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        temp_max.append(response['main']['temp_max'])
        
    #Passes any time a city name is not available     
    except KeyError:
        pass

# %%
# Create dictionary using lists and column names to reference
city_data_dict = {
    'City Name': name,
    'Temperature': temp,
    'Humidity': humid,
    'Cloudiness': cloud,
    'Wind Speed': wind,
    'Country': country,
    'Latitude': lat,
    'Longitude': long,
    'Date': date
    
}

# Create dataframe from dictionary
city_data_df = pd.DataFrame(city_data_dict)
city_data_df.head()
# Out:
#       City Name  Temperature  Humidity  Cloudiness  Wind Speed Country  \
# 0  Puerto Ayora        82.40        74          75        9.17      EC
# 1          Kaeo        78.37        51           0        5.99      NZ
# 2  Punta Arenas        44.46       100          40       23.04      CL
# 3        Castro        53.60        81          75       12.75      CL
# 4      Saldanha        40.76        84          48        2.93      PT
#
#    Latitude  Longitude        Date
# 0     -0.74     -90.35  1551740400
# 1    -35.10     173.78  1551744485
# 2    -53.16     -70.91  1551744808
# 3    -42.48     -73.76  1551740400
# 4     41.42      -6.55  1551744883

# %%
# Display number of rows
city_data_df.count()
# Out:
# City Name      524
# Temperature    524
# Humidity       524
# Cloudiness     524
# Wind Speed     524
# Country        524
# Latitude       524
# Longitude      524
# Date           524
# dtype: int64

# %%
# Save dataframe to CSV file
city_data_df.to_csv("city_data.csv", encoding="utf-8", index=False)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Create Scatter Plot
plt.scatter(lat, temp_max, marker="o", facecolors="lightgreen", edgecolors="black",
            s=40, alpha=0.75)

# Set a Title and labels
plt.title("City Latitude vs Max Temperature (3/4/2019)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

# Show and save
plt.show()
plt.savefig("../Images/lat_vs_max_temp.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Create Scatter Plot
plt.scatter(lat, humid, marker="o", facecolors="lightgreen", edgecolors="black",
            s=40, alpha=0.75)

# Set a Title and labels
plt.title("City Latitude vs Humidity (3/4/2019)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Show and save
plt.show()
plt.savefig("../Images/lat_vs_humidity.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Create Scatter Plot
plt.scatter(lat, cloud, marker="o", facecolors="lightgreen", edgecolors="black",
            s=40, alpha=0.75)

# Set a Title and labels
plt.title("City Latitude vs Cloudiness (3/4/2019)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Show and save
plt.show()
plt.savefig("../Images/lat_vs_cloudiness.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Create Scatter Plot
plt.scatter(lat, wind, marker="o", facecolors="lightgreen", edgecolors="black",
            s=40, alpha=0.75)

# Set a Title and labels
plt.title("City Latitude vs Wind Speed (3/4/2019)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# Show and save
plt.show()
plt.savefig("../Images/lat_vs_wind_speed.png")
