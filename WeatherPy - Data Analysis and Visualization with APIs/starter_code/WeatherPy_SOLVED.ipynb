# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the SOUTHERN hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth. (For example: It is considered "summer" this time of year in places like Australia).
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
import config
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 623

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=25d95a902b40b8567c1cf7c2534a5333&units=imperial&q='

# %%
# list for response results
temp = []
counter = 1
set = 1

# loop through cities, make API request, and append desired results
for city in cities:
    try:
        response = requests.get(query_url + city).json()
        temp.append(response['main']['temp'])
        print(f'Processing Record {counter} of Set {set} | {city}')
        counter +=1
        
        if counter >50:
            set +=1
            counter = 1
        
    except KeyError:
        print(f'City not found. Skipping...')
        pass
# Out:
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | pacific grove
# Processing Record 3 of Set 1 | muslyumovo
# City not found. Skipping...
# Processing Record 4 of Set 1 | nizhneangarsk
# Processing Record 5 of Set 1 | soto la marina
# Processing Record 6 of Set 1 | kushiro
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 7 of Set 1 | esperance
# Processing Record 8 of Set 1 | airai
# Processing Record 9 of Set 1 | narsaq
# Processing Record 10 of Set 1 | carnarvon
# Processing Record 11 of Set 1 | hailar
# Processing Record 12 of Set 1 | kodiak
# Processing Record 13 of Set 1 | chuy
# Processing Record 14 of Set 1 | jacareacanga
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | yellowknife
# Processing Record 17 of Set 1 | busselton
# Processing Record 18 of Set 1 | lubao
# Processing Record 19 of Set 1 | loandjili
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | avarua
# City not found. Skipping...
# Processing Record 22 of Set 1 | markapur
# Processing Record 23 of Set 1 | aklavik
# Processing Record 24 of Set 1 | bethel
# Processing Record 25 of Set 1 | bayan
# Processing Record 26 of Set 1 | kavieng
# Processing Record 27 of Set 1 | saskylakh
# City not found. Skipping...
# Processing Record 28 of Set 1 | ilulissat
# Processing Record 29 of Set 1 | atuona
# Processing Record 30 of Set 1 | vaini
# Processing Record 31 of Set 1 | chicama
# Processing Record 32 of Set 1 | tevaitoa
# Processing Record 33 of Set 1 | jamestown
# Processing Record 34 of Set 1 | port-gentil
# Processing Record 35 of Set 1 | hilo
# City not found. Skipping...
# Processing Record 36 of Set 1 | tuatapere
# Processing Record 37 of Set 1 | kapaa
# Processing Record 38 of Set 1 | srednekolymsk
# Processing Record 39 of Set 1 | casper
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 40 of Set 1 | guerrero negro
# Processing Record 41 of Set 1 | khatanga
# Processing Record 42 of Set 1 | victoria
# City not found. Skipping...
# Processing Record 43 of Set 1 | mataura
# Processing Record 44 of Set 1 | tuktoyaktuk
# Processing Record 45 of Set 1 | georgetown
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 46 of Set 1 | cape town
# Processing Record 47 of Set 1 | albany
# Processing Record 48 of Set 1 | mahebourg
# Processing Record 49 of Set 1 | constitucion
# Processing Record 50 of Set 1 | butaritari
# Processing Record 1 of Set 2 | torbay
# Processing Record 2 of Set 2 | matay
# Processing Record 3 of Set 2 | chokurdakh
# Processing Record 4 of Set 2 | witu
# Processing Record 5 of Set 2 | nikolskoye
# Processing Record 6 of Set 2 | ketchikan
# Processing Record 7 of Set 2 | topeka
# City not found. Skipping...
# Processing Record 8 of Set 2 | batticaloa
# Processing Record 9 of Set 2 | mirabad
# Processing Record 10 of Set 2 | port blair
# Processing Record 11 of Set 2 | port alfred
# Processing Record 12 of Set 2 | samfya
# Processing Record 13 of Set 2 | yuanping
# Processing Record 14 of Set 2 | szigetvar
# Processing Record 15 of Set 2 | hithadhoo
# Processing Record 16 of Set 2 | grand-santi
# Processing Record 17 of Set 2 | mar del plata
# City not found. Skipping...
# Processing Record 18 of Set 2 | moussoro
# Processing Record 19 of Set 2 | grindavik
# Processing Record 20 of Set 2 | hermanus
# Processing Record 21 of Set 2 | luderitz
# Processing Record 22 of Set 2 | east london
# Processing Record 23 of Set 2 | burpengary
# Processing Record 24 of Set 2 | baykit
# Processing Record 25 of Set 2 | nemuro
# Processing Record 26 of Set 2 | high prairie
# Processing Record 27 of Set 2 | kijang
# Processing Record 28 of Set 2 | arlit
# Processing Record 29 of Set 2 | scottsbluff
# Processing Record 30 of Set 2 | talisay
# Processing Record 31 of Set 2 | port elizabeth
# Processing Record 32 of Set 2 | hervey bay
# Processing Record 33 of Set 2 | longyearbyen
# Processing Record 34 of Set 2 | new norfolk
# Processing Record 35 of Set 2 | lavrentiya
# Processing Record 36 of Set 2 | barrow
# Processing Record 37 of Set 2 | orcopampa
# Processing Record 38 of Set 2 | carpinteria
# Processing Record 39 of Set 2 | coihaique
# Processing Record 40 of Set 2 | laguna
# Processing Record 41 of Set 2 | dikson
# Processing Record 42 of Set 2 | san patricio
# Processing Record 43 of Set 2 | rostovka
# Processing Record 44 of Set 2 | manokwari
# Processing Record 45 of Set 2 | saldanha
# Processing Record 46 of Set 2 | yumen
# Processing Record 47 of Set 2 | farafangana
# Processing Record 48 of Set 2 | bushehr
# Processing Record 49 of Set 2 | bucerias
# Processing Record 50 of Set 2 | hobart
# Processing Record 1 of Set 3 | pevek
# Processing Record 2 of Set 3 | faanui
# Processing Record 3 of Set 3 | furano
# Processing Record 4 of Set 3 | havelock
# Processing Record 5 of Set 3 | taoudenni
# Processing Record 6 of Set 3 | amalfi
# City not found. Skipping...
# Processing Record 7 of Set 3 | kampene
# Processing Record 8 of Set 3 | kirakira
# Processing Record 9 of Set 3 | bluff
# Processing Record 10 of Set 3 | ormond beach
# Processing Record 11 of Set 3 | upernavik
# Processing Record 12 of Set 3 | ust-omchug
# Processing Record 13 of Set 3 | whitehorse
# Processing Record 14 of Set 3 | rocha
# Processing Record 15 of Set 3 | chenzhou
# Processing Record 16 of Set 3 | souillac
# Processing Record 17 of Set 3 | acapulco
# Processing Record 18 of Set 3 | torremolinos
# Processing Record 19 of Set 3 | qaanaaq
# Processing Record 20 of Set 3 | riyadh
# Processing Record 21 of Set 3 | talnakh
# Processing Record 22 of Set 3 | rodbyhavn
# Processing Record 23 of Set 3 | saint-philippe
# Processing Record 24 of Set 3 | ozernovskiy
# Processing Record 25 of Set 3 | coronado
# Processing Record 26 of Set 3 | verkhoyansk
# Processing Record 27 of Set 3 | santiago
# Processing Record 28 of Set 3 | nanortalik
# Processing Record 29 of Set 3 | lincoln
# Processing Record 30 of Set 3 | champerico
# Processing Record 31 of Set 3 | beira
# Processing Record 32 of Set 3 | clyde river
# Processing Record 33 of Set 3 | carutapera
# Processing Record 34 of Set 3 | ongole
# City not found. Skipping...
# Processing Record 35 of Set 3 | magadan
# Processing Record 36 of Set 3 | upata
# Processing Record 37 of Set 3 | port lincoln
# Processing Record 38 of Set 3 | fort payne
# Processing Record 39 of Set 3 | camacha
# Processing Record 40 of Set 3 | novyy nekouz
# Processing Record 41 of Set 3 | zapolyarnyy
# City not found. Skipping...
# Processing Record 42 of Set 3 | wonthaggi
# Processing Record 43 of Set 3 | thompson
# Processing Record 44 of Set 3 | pamekasan
# City not found. Skipping...
# Processing Record 45 of Set 3 | lebu
# Processing Record 46 of Set 3 | manaure
# Processing Record 47 of Set 3 | itacare
# Processing Record 48 of Set 3 | havoysund
# Processing Record 49 of Set 3 | wuda
# Processing Record 50 of Set 3 | sakaiminato
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 1 of Set 4 | bogovarovo
# Processing Record 2 of Set 4 | cidreira
# Processing Record 3 of Set 4 | dabat
# Processing Record 4 of Set 4 | kyzyl
# Processing Record 5 of Set 4 | ponoka
# Processing Record 6 of Set 4 | tasiilaq
# Processing Record 7 of Set 4 | kinkala
# Processing Record 8 of Set 4 | north bend
# City not found. Skipping...
# Processing Record 9 of Set 4 | castro
# Processing Record 10 of Set 4 | klyuchi
# Processing Record 11 of Set 4 | siniscola
# Processing Record 12 of Set 4 | alofi
# Processing Record 13 of Set 4 | nakambala
# Processing Record 14 of Set 4 | blagoevgrad
# Processing Record 15 of Set 4 | barquisimeto
# Processing Record 16 of Set 4 | yar-sale
# Processing Record 17 of Set 4 | saint george
# Processing Record 18 of Set 4 | vardo
# Processing Record 19 of Set 4 | konevo
# Processing Record 20 of Set 4 | ishigaki
# Processing Record 21 of Set 4 | tiksi
# Processing Record 22 of Set 4 | arraial do cabo
# Processing Record 23 of Set 4 | quatre cocos
# Processing Record 24 of Set 4 | ponta do sol
# Processing Record 25 of Set 4 | san cristobal
# Processing Record 26 of Set 4 | meulaboh
# Processing Record 27 of Set 4 | geraldton
# Processing Record 28 of Set 4 | unai
# Processing Record 29 of Set 4 | provideniya
# Processing Record 30 of Set 4 | sao joao da barra
# Processing Record 31 of Set 4 | dogondoutchi
# Processing Record 32 of Set 4 | muros
# Processing Record 33 of Set 4 | touros
# Processing Record 34 of Set 4 | caravelas
# Processing Record 35 of Set 4 | muhos
# City not found. Skipping...
# Processing Record 36 of Set 4 | kaitangata
# Processing Record 37 of Set 4 | pechora
# Processing Record 38 of Set 4 | vanavara
# Processing Record 39 of Set 4 | bredasdorp
# Processing Record 40 of Set 4 | raudeberg
# Processing Record 41 of Set 4 | saint-joseph
# Processing Record 42 of Set 4 | biak
# Processing Record 43 of Set 4 | wenling
# Processing Record 44 of Set 4 | hambantota
# Processing Record 45 of Set 4 | la ronge
# Processing Record 46 of Set 4 | upington
# Processing Record 47 of Set 4 | severo-kurilsk
# Processing Record 48 of Set 4 | gorontalo
# City not found. Skipping...
# Processing Record 49 of Set 4 | itaituba
# City not found. Skipping...
# Processing Record 50 of Set 4 | mogadishu
# Processing Record 1 of Set 5 | aripuana
# Processing Record 2 of Set 5 | santa marta
# Processing Record 3 of Set 5 | buritama
# Processing Record 4 of Set 5 | osypenko
# Processing Record 5 of Set 5 | pontes e lacerda
# Processing Record 6 of Set 5 | klaksvik
# City not found. Skipping...
# Processing Record 7 of Set 5 | coulommiers
# Processing Record 8 of Set 5 | puerto escondido
# Processing Record 9 of Set 5 | erenhot
# Processing Record 10 of Set 5 | stranda
# City not found. Skipping...
# Processing Record 11 of Set 5 | tigil
# Processing Record 12 of Set 5 | shelburne
# Processing Record 13 of Set 5 | sitka
# Processing Record 14 of Set 5 | rawson
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 15 of Set 5 | asyut
# Processing Record 16 of Set 5 | moose factory
# Processing Record 17 of Set 5 | los palacios
# Processing Record 18 of Set 5 | bhawanipatna
# Processing Record 19 of Set 5 | broken hill
# Processing Record 20 of Set 5 | saint pete beach
# Processing Record 21 of Set 5 | lethem
# Processing Record 22 of Set 5 | xining
# Processing Record 23 of Set 5 | cabo san lucas
# Processing Record 24 of Set 5 | port shepstone
# Processing Record 25 of Set 5 | shubarshi
# Processing Record 26 of Set 5 | okhotsk
# Processing Record 27 of Set 5 | sur
# Processing Record 28 of Set 5 | juneau
# Processing Record 29 of Set 5 | coquimbo
# Processing Record 30 of Set 5 | beringovskiy
# Processing Record 31 of Set 5 | merauke
# Processing Record 32 of Set 5 | los llanos de aridane
# Processing Record 33 of Set 5 | natal
# Processing Record 34 of Set 5 | nixa
# Processing Record 35 of Set 5 | bosaso
# Processing Record 36 of Set 5 | norman wells
# Processing Record 37 of Set 5 | san gabriel
# City not found. Skipping...
# Processing Record 38 of Set 5 | ahipara
# Processing Record 39 of Set 5 | svetlogorsk
# Processing Record 40 of Set 5 | ust-maya
# Processing Record 41 of Set 5 | iranshahr
# Processing Record 42 of Set 5 | avera
# Processing Record 43 of Set 5 | khani
# Processing Record 44 of Set 5 | puerto ayora
# Processing Record 45 of Set 5 | camopi
# Processing Record 46 of Set 5 | puerto madero
# Processing Record 47 of Set 5 | semiletka
# Processing Record 48 of Set 5 | kungurtug
# Processing Record 49 of Set 5 | fare
# Processing Record 50 of Set 5 | bonthe
# Processing Record 1 of Set 6 | hofn
# Processing Record 2 of Set 6 | jaunpur
# Processing Record 3 of Set 6 | dunedin
# Processing Record 4 of Set 6 | primo tapia
# Processing Record 5 of Set 6 | megalopoli
# Processing Record 6 of Set 6 | bedworth
# Processing Record 7 of Set 6 | victoria point
# Processing Record 8 of Set 6 | matara
# Processing Record 9 of Set 6 | ati
# Processing Record 10 of Set 6 | bud
# Processing Record 11 of Set 6 | deputatskiy
# Processing Record 12 of Set 6 | gedo
# Processing Record 13 of Set 6 | lodja
# Processing Record 14 of Set 6 | havre-saint-pierre
# Processing Record 15 of Set 6 | seymchan
# Processing Record 16 of Set 6 | flinders
# Processing Record 17 of Set 6 | suluq
# Processing Record 18 of Set 6 | kalabo
# Processing Record 19 of Set 6 | vestmannaeyjar
# Processing Record 20 of Set 6 | naze
# Processing Record 21 of Set 6 | tanete
# Processing Record 22 of Set 6 | alvaraes
# Processing Record 23 of Set 6 | abu samrah
# City not found. Skipping...
# Processing Record 24 of Set 6 | port hawkesbury
# Processing Record 25 of Set 6 | dawson creek
# Processing Record 26 of Set 6 | aden
# Processing Record 27 of Set 6 | poya
# Processing Record 28 of Set 6 | lumut
# Processing Record 29 of Set 6 | lanzhou
# Processing Record 30 of Set 6 | chumikan
# Processing Record 31 of Set 6 | buala
# Processing Record 32 of Set 6 | nhulunbuy
# Processing Record 33 of Set 6 | sola
# Processing Record 34 of Set 6 | bouca
# Processing Record 35 of Set 6 | vila franca do campo
# Processing Record 36 of Set 6 | corning
# Processing Record 37 of Set 6 | salalah
# Processing Record 38 of Set 6 | goure
# Processing Record 39 of Set 6 | colombia
# Processing Record 40 of Set 6 | tari
# Processing Record 41 of Set 6 | brejo da madre de deus
# Processing Record 42 of Set 6 | kudahuvadhoo
# Processing Record 43 of Set 6 | rio gallegos
# City not found. Skipping...
# Processing Record 44 of Set 6 | khorixas
# Processing Record 45 of Set 6 | cravo norte
# Processing Record 46 of Set 6 | kurilsk
# Processing Record 47 of Set 6 | zhezkazgan
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 48 of Set 6 | challans
# Processing Record 49 of Set 6 | nuevo progreso
# Processing Record 50 of Set 6 | soria
# Processing Record 1 of Set 7 | srandakan
# City not found. Skipping...
# Processing Record 2 of Set 7 | collie
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 3 of Set 7 | fort saint james
# Processing Record 4 of Set 7 | rio grande
# City not found. Skipping...
# Processing Record 5 of Set 7 | abha
# Processing Record 6 of Set 7 | mansa
# Processing Record 7 of Set 7 | najran
# Processing Record 8 of Set 7 | atakpame
# Processing Record 9 of Set 7 | kieta
# Processing Record 10 of Set 7 | longyan
# Processing Record 11 of Set 7 | baft
# Processing Record 12 of Set 7 | waipawa
# Processing Record 13 of Set 7 | college
# Processing Record 14 of Set 7 | saint-leu
# Processing Record 15 of Set 7 | dwarka
# Processing Record 16 of Set 7 | nabire
# Processing Record 17 of Set 7 | nyurba
# City not found. Skipping...
# Processing Record 18 of Set 7 | belyy yar
# Processing Record 19 of Set 7 | waverly
# Processing Record 20 of Set 7 | baghdad
# Processing Record 21 of Set 7 | vostok
# Processing Record 22 of Set 7 | itarema
# Processing Record 23 of Set 7 | imeni poliny osipenko
# Processing Record 24 of Set 7 | kahului
# Processing Record 25 of Set 7 | kankaanpaa
# City not found. Skipping...
# Processing Record 26 of Set 7 | sosnovka
# Processing Record 27 of Set 7 | abaete
# Processing Record 28 of Set 7 | vanimo
# Processing Record 29 of Set 7 | tautira
# City not found. Skipping...
# Processing Record 30 of Set 7 | tynda
# Processing Record 31 of Set 7 | qaqortoq
# Processing Record 32 of Set 7 | avesta
# Processing Record 33 of Set 7 | fairbanks
# Processing Record 34 of Set 7 | hillsborough
# Processing Record 35 of Set 7 | mwandiga
# Processing Record 36 of Set 7 | ucluelet
# Processing Record 37 of Set 7 | kingaroy
# Processing Record 38 of Set 7 | yulara
# Processing Record 39 of Set 7 | ostrovnoy
# City not found. Skipping...
# Processing Record 40 of Set 7 | ostersund
# Processing Record 41 of Set 7 | kendari
# Processing Record 42 of Set 7 | ejea de los caballeros
# Processing Record 43 of Set 7 | kattivakkam
# Processing Record 44 of Set 7 | beidao
# Processing Record 45 of Set 7 | hobbs
# Processing Record 46 of Set 7 | jaisalmer
# Processing Record 47 of Set 7 | chipinge
# Processing Record 48 of Set 7 | boddam
# Processing Record 49 of Set 7 | scarborough
# Processing Record 50 of Set 7 | muli
# Processing Record 1 of Set 8 | sinnamary
# Processing Record 2 of Set 8 | koshurnikovo
# Processing Record 3 of Set 8 | steamboat springs
# Processing Record 4 of Set 8 | maniitsoq
# Processing Record 5 of Set 8 | dingle
# Processing Record 6 of Set 8 | hovd
# City not found. Skipping...
# Processing Record 7 of Set 8 | birin
# Processing Record 8 of Set 8 | radomsko
# City not found. Skipping...
# Processing Record 9 of Set 8 | baiyin
# City not found. Skipping...
# Processing Record 10 of Set 8 | nevsehir
# Processing Record 11 of Set 8 | mhlume
# City not found. Skipping...
# Processing Record 12 of Set 8 | ancud
# Processing Record 13 of Set 8 | ribeira grande
# Processing Record 14 of Set 8 | vao
# Processing Record 15 of Set 8 | kem
# City not found. Skipping...
# Processing Record 16 of Set 8 | fuling
# Processing Record 17 of Set 8 | ulladulla
# Processing Record 18 of Set 8 | kargasok
# Processing Record 19 of Set 8 | bytosh
# Processing Record 20 of Set 8 | vila velha
# City not found. Skipping...
# Processing Record 21 of Set 8 | portland
# City not found. Skipping...
# Processing Record 22 of Set 8 | comodoro rivadavia
# Processing Record 23 of Set 8 | jiexiu
# Processing Record 24 of Set 8 | bubaque
# Processing Record 25 of Set 8 | sharjah
# Processing Record 26 of Set 8 | ujhani
# Processing Record 27 of Set 8 | waitati
# Processing Record 28 of Set 8 | pierre
# Processing Record 29 of Set 8 | severomuysk
# Processing Record 30 of Set 8 | caibarien
# Processing Record 31 of Set 8 | tacuarembo
# City not found. Skipping...
# Processing Record 32 of Set 8 | gumdag
# Processing Record 33 of Set 8 | hamilton
# Processing Record 34 of Set 8 | hasaki
# Processing Record 35 of Set 8 | lerwick
# Processing Record 36 of Set 8 | bambous virieux
# Processing Record 37 of Set 8 | saint-augustin
# Processing Record 38 of Set 8 | kirovsk
# Processing Record 39 of Set 8 | meadow lake
# Processing Record 40 of Set 8 | bonavista
# Processing Record 41 of Set 8 | tambun
# Processing Record 42 of Set 8 | twentynine palms
# Processing Record 43 of Set 8 | mantua
# Processing Record 44 of Set 8 | barranca
# Processing Record 45 of Set 8 | roald
# Processing Record 46 of Set 8 | gladstone
# Processing Record 47 of Set 8 | poum
# Processing Record 48 of Set 8 | berdigestyakh
# Processing Record 49 of Set 8 | fortuna
# Processing Record 50 of Set 8 | samana
# Processing Record 1 of Set 9 | semnan
# Processing Record 2 of Set 9 | port keats
# Processing Record 3 of Set 9 | zyryanka
# Processing Record 4 of Set 9 | makokou
# Processing Record 5 of Set 9 | predejane
# Processing Record 6 of Set 9 | nakusp
# Processing Record 7 of Set 9 | campana
# Processing Record 8 of Set 9 | lata
# Processing Record 9 of Set 9 | urucara
# Processing Record 10 of Set 9 | nuuk
# Processing Record 11 of Set 9 | zambezi
# City not found. Skipping...
# Processing Record 12 of Set 9 | sisimiut
# Processing Record 13 of Set 9 | kruisfontein
# Processing Record 14 of Set 9 | half moon bay
# Processing Record 15 of Set 9 | palmer
# Processing Record 16 of Set 9 | almaznyy
# Processing Record 17 of Set 9 | madimba
# Processing Record 18 of Set 9 | pisco
# Processing Record 19 of Set 9 | minamata
# Processing Record 20 of Set 9 | kingisepp
# Processing Record 21 of Set 9 | nioro
# Processing Record 22 of Set 9 | ocampo
# Processing Record 23 of Set 9 | mount gambier
# Processing Record 24 of Set 9 | mastic beach
# Processing Record 25 of Set 9 | suntar
# Processing Record 26 of Set 9 | tucupita
# Processing Record 27 of Set 9 | san fernando
# Processing Record 28 of Set 9 | sepolno krajenskie
# Processing Record 29 of Set 9 | madinat sittah uktubar
# Processing Record 30 of Set 9 | manaus
# City not found. Skipping...
# Processing Record 31 of Set 9 | baijiantan
# Processing Record 32 of Set 9 | maltahohe
# Processing Record 33 of Set 9 | turochak
# Processing Record 34 of Set 9 | codrington
# Processing Record 35 of Set 9 | ambovombe
# Processing Record 36 of Set 9 | gat
# Processing Record 37 of Set 9 | lorengau
# Processing Record 38 of Set 9 | roebourne
# Processing Record 39 of Set 9 | nouadhibou
# Processing Record 40 of Set 9 | iqaluit
# Processing Record 41 of Set 9 | campo maior
# Processing Record 42 of Set 9 | moroto
# Processing Record 43 of Set 9 | tezu
# Processing Record 44 of Set 9 | gizo
# Processing Record 45 of Set 9 | sibi
# Processing Record 46 of Set 9 | chernyshevskiy
# Processing Record 47 of Set 9 | hilton head island
# Processing Record 48 of Set 9 | gamboma
# Processing Record 49 of Set 9 | santa isabel do rio negro
# Processing Record 50 of Set 9 | golspie
# Processing Record 1 of Set 10 | hongjiang
# Processing Record 2 of Set 10 | saint-francois
# Processing Record 3 of Set 10 | sao filipe
# Processing Record 4 of Set 10 | saint anthony
# Processing Record 5 of Set 10 | solnechnyy
# City not found. Skipping...
# Processing Record 6 of Set 10 | road town
# Processing Record 7 of Set 10 | nishihara
# Processing Record 8 of Set 10 | melbourne
# Processing Record 9 of Set 10 | kavaratti
# Processing Record 10 of Set 10 | dabola
# Processing Record 11 of Set 10 | jalu
# City not found. Skipping...
# Processing Record 12 of Set 10 | limon
# Processing Record 13 of Set 10 | sept-iles
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 14 of Set 10 | aleksandrovskoye
# Processing Record 15 of Set 10 | oskarshamn
# Processing Record 16 of Set 10 | xinyu
# Processing Record 17 of Set 10 | kulhudhuffushi
# Processing Record 18 of Set 10 | ust-kan
# Processing Record 19 of Set 10 | dawei
# Processing Record 20 of Set 10 | anadyr
# Processing Record 21 of Set 10 | san joaquin
# Processing Record 22 of Set 10 | santiago de chuco
# Processing Record 23 of Set 10 | nome
# Processing Record 24 of Set 10 | labuhan
# City not found. Skipping...
# Processing Record 25 of Set 10 | moron
# Processing Record 26 of Set 10 | kyzyl-suu
# Processing Record 27 of Set 10 | awjilah
# Processing Record 28 of Set 10 | cururupu
# Processing Record 29 of Set 10 | tabuk
# City not found. Skipping...
# Processing Record 30 of Set 10 | edd
# Processing Record 31 of Set 10 | erzin
# Processing Record 32 of Set 10 | mehamn
# Processing Record 33 of Set 10 | westport
# Processing Record 34 of Set 10 | bac ninh
# Processing Record 35 of Set 10 | qeshm
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 36 of Set 10 | luau
# Processing Record 37 of Set 10 | urusha
# Processing Record 38 of Set 10 | huarmey
# City not found. Skipping...
# Processing Record 39 of Set 10 | felanitx
# Processing Record 40 of Set 10 | viseu
# Processing Record 41 of Set 10 | noumea
# Processing Record 42 of Set 10 | kangaatsiaq
# Processing Record 43 of Set 10 | bocas del toro
# Processing Record 44 of Set 10 | parabel
# Processing Record 45 of Set 10 | leningradskiy
# Processing Record 46 of Set 10 | te anau
# Processing Record 47 of Set 10 | vytegra
# Processing Record 48 of Set 10 | evanston
# Processing Record 49 of Set 10 | mareeba
# Processing Record 50 of Set 10 | ust-nera
# Processing Record 1 of Set 11 | ternate
# Processing Record 2 of Set 11 | santa fe
# Processing Record 3 of Set 11 | tucuman
# Processing Record 4 of Set 11 | sao felix do xingu
# Processing Record 5 of Set 11 | pereslavl-zalesskiy
# Processing Record 6 of Set 11 | wajima
# Processing Record 7 of Set 11 | hay river
# Processing Record 8 of Set 11 | gazanjyk
# Processing Record 9 of Set 11 | buraydah
# Processing Record 10 of Set 11 | raton
# Processing Record 11 of Set 11 | beloha
# Processing Record 12 of Set 11 | kharp
# Processing Record 13 of Set 11 | ulaanbaatar
# Processing Record 14 of Set 11 | necochea
# Processing Record 15 of Set 11 | konstantinovo
# Processing Record 16 of Set 11 | mayumba
# Processing Record 17 of Set 11 | lake city
# Processing Record 18 of Set 11 | dombarovskiy
# Processing Record 19 of Set 11 | shakawe
# City not found. Skipping...
# Processing Record 20 of Set 11 | isangel
# Processing Record 21 of Set 11 | mul
# Processing Record 22 of Set 11 | nyzhnya duvanka
# Processing Record 23 of Set 11 | bronnoysund
# Processing Record 24 of Set 11 | alta floresta
# Processing Record 25 of Set 11 | darnah
# Processing Record 26 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 27 of Set 11 | zhigansk
# Processing Record 28 of Set 11 | hualmay
# Processing Record 29 of Set 11 | weiser
# Processing Record 30 of Set 11 | berlevag
# Processing Record 31 of Set 11 | malinovoye ozero
# Processing Record 32 of Set 11 | rundu
# Processing Record 33 of Set 11 | aasiaat
# Processing Record 34 of Set 11 | carbondale
# Processing Record 35 of Set 11 | gamba
# Processing Record 36 of Set 11 | puerto baquerizo moreno
# Processing Record 37 of Set 11 | spring valley
# Processing Record 38 of Set 11 | corrales
# Processing Record 39 of Set 11 | margate
# Processing Record 40 of Set 11 | dakoro
# Processing Record 41 of Set 11 | kamsack
# Processing Record 42 of Set 11 | santiago de cao
# Processing Record 43 of Set 11 | harqalah
# Processing Record 44 of Set 11 | banjar
# Processing Record 45 of Set 11 | longonjo
# Processing Record 46 of Set 11 | samarai

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Create dictionary with all variables, called from the API
name = []
temp = []
humid = []
cloud = []
wind = []
lat = []
long = []
country = []
date = []
temp_max = []

# loop through cities, make API request, and append desired results to list names
for city in cities:
    try:
        response = requests.get(query_url + city).json()
        name.append(response['name'])
        humid.append(response['main']['humidity'])
        temp.append(response['main']['temp'])
        cloud.append(response['clouds']['all'])
        wind.append(response['wind']['speed'])
        lat.append(response['coord']['lat'])
        long.append(response['coord']['lon'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        temp_max.append(response['main']['temp_max'])
        
    #Passes any time a city name is not available     
    except KeyError:
        pass

# %%
# Create dictionary using lists and column names to reference
city_data_dict = {
    'City Name': name,
    'Temperature': temp,
    'Humidity': humid,
    'Cloudiness': cloud,
    'Wind Speed': wind,
    'Country': country,
    'Latitude': lat,
    'Longitude': long,
    'Date': date  
}

# Create dataframe from dictionary
city_data_df = pd.DataFrame(city_data_dict)
city_data_df.head()
# Out:
#         City Name  Temperature  Humidity  Cloudiness  Wind Speed Country  \
# 0         Bowmore        75.78        29           1       12.75      US
# 1           Kieta        77.62       100          92        4.05      PG
# 2  Saint-Philippe        37.27        64           1        6.93      CA
# 3   Mar del Plata        60.34        50           0        3.94      AR
# 4         Makasar        80.29        78          20        8.05      ID
#
#    Latitude  Longitude        Date
# 0     34.94     -79.30  1554921932
# 1     -6.22     155.63  1554921971
# 2     45.36     -73.48  1554921957
# 3    -46.43     -67.52  1554921971
# 4     -6.28     106.88  1554921748

# %%
# Display number of rows
city_data_df.count()
# Out:
# City Name      561
# Temperature    561
# Humidity       561
# Cloudiness     561
# Wind Speed     561
# Country        561
# Latitude       561
# Longitude      561
# Date           561
# dtype: int64

# %%
# Save dataframe to CSV file
city_data_df.to_csv("city_data.csv", encoding="utf-8", index=False)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Create Scatter Plot
plt.scatter(lat, temp_max, marker="o", facecolors="lightgreen", edgecolors="black",
            s=40, alpha=0.75)

# Get today's date
import datetime
d = datetime.datetime.today()
 
# Converting date into DD-MM-YYYY format
d_conv = d.strftime('%m-%d-%Y')

# Set a Title and labels
plt.title(f"City Latitude vs Max Temperature {d_conv}")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

# Save and Show
plt.savefig("../Images/lat_vs_max_temp.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Create Scatter Plot
plt.scatter(lat, humid, marker="o", facecolors="lightgreen", edgecolors="black",
            s=40, alpha=0.75)

# Set a Title and labels
plt.title(f"City Latitude vs Humidity {d_conv}")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Save and Show
plt.savefig("../Images/lat_vs_humidity.png")
plt.show()

# %%
# The previous humidity chart had one outlier, so drop outlier point and re-plot
city_data_df = city_data_df.sort_values(by=['Humidity'], ascending= False)
city_data_df = city_data_df.iloc[1:]
humid2 = city_data_df['Humidity'].tolist()
lat2 = city_data_df['Latitude'].tolist()

# Create Scatter Plot
plt.scatter(lat2, humid2, marker="o", facecolors="lightgreen", edgecolors="black",
            s=40, alpha=0.75)

# Set a Title and labels
plt.title(f"City Latitude vs Humidity {d_conv}")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Save and Show
plt.savefig("../Images/lat_vs_humidity_fixed.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Create Scatter Plot
plt.scatter(lat, cloud, marker="o", facecolors="lightgreen", edgecolors="black",
            s=40, alpha=0.75)

# Set a Title and labels
plt.title(f"City Latitude vs Cloudiness {d_conv}")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# # Save and Show
plt.savefig("../Images/lat_vs_cloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Create Scatter Plot
plt.scatter(lat, wind, marker="o", facecolors="lightgreen", edgecolors="black",
            s=40, alpha=0.75)

# Set a Title and labels
plt.title(f"City Latitude vs Wind Speed {d_conv}")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# Save and Show
plt.savefig("../Images/lat_vs_wind_speed.png")
plt.show()
